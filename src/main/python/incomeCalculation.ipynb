# %%
import pandas as pd


person = pd.read_csv(
    "/Users/gregorr/Documents/work/respos/public-svn/matsim/scenarios/countries/de/berlin/berlin-v6.4/output/berlin-v6.4-10pct/berlin-v6.4.output_persons.csv.gz",
    sep=";",
    low_memory=False,
    compression="gzip"
)

mean_income = person["income"].mean()
print(mean_income)
# Out:
# 1942.3619870392838
